# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images, imsave
from skimage.transform import resize
from skimage.morphology import label


from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# Altura y Ancho de la imagen y los canales RGB
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

TRAIN_PATH = '/home/quiquealon/Documents/TIA/UNET/ISIC2018_Task1-2_Training_Input/'
MASK_PATH = '/home/quiquealon/Documents/TIA/UNET/ISIC2018_Task1_Training_GroundTruth/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
# Tomar los datos para train y test

train_ids = next(os.walk(TRAIN_PATH))[2]



X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-6-f89f4fb3ccd8> in <module>
#       1 # Tomar los datos para train y test
#       2
# ----> 3 train_ids = next(os.walk(TRAIN_PATH))[2]
#       4 test_ids = next(os.walk(TEST_PATH))[2]
#       5
#
# StopIteration:

# %%
print('Obteniendo y redimensionando imágenes de entrenamiento y máscaras. ... ')

sys.stdout.flush()

for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    
    path = TRAIN_PATH + id_
    img = imread(path)[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    
    #Redimensionar la mascara la mascara
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    path_mask=MASK_PATH + id_[:-4] + '_segmentation.png'
    img_mask = imread(path_mask)
    img_mask = np.expand_dims(resize(img_mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',preserve_range=True), axis=-1)
    
    Y_train[n]=img_mask
    
    

print('Preprocesamiento Terminado!')
# Out:
# Obteniendo y redimensionando imágenes de entrenamiento y máscaras. ...
#   0%|          | 0/2594 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f3db9089ce8c> in <module>
#      17     img_mask = np.expand_dims(resize(img_mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',preserve_range=True), axis=-1)
#      18
# ---> 19     mask = np.maximum(mask, mask_)
#      20     Y_train[n]=img_mask
#      21
#
# NameError: name 'mask_' is not defined

# %%
# Guardar la data redimensionada del train

Y_train_int=np.array(np.squeeze(Y_train),dtype='int')

for id_ in tqdm(range(len(X_train)),total=len(X_train)):
    imsave('ISIC2018_Task1-2_Training_Input - redimensionada/' + train_ids[id_],X_train[id_])
    imsave('ISIC2018_Task1_Training_GroundTruth- redimensionada/' + train_ids[id_][:-4]+ '_segmentation.png',Y_train_int[id_])
# Out:
#   0%|          | 0/2594 [00:00<?, ?it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   0%|          | 12/2594 [00:00<00:21, 118.85it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|          | 29/2594 [00:00<00:19, 129.96it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|▏         | 49/2594 [00:00<00:17, 144.61it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   3%|▎         | 67/2594 [00:00<00:16, 152.98it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   3%|▎         | 84/2594 [00:00<00:16, 156.71it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|▍         | 104/2594 [00:00<00:14, 167.22it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   5%|▍         | 124/2594 [00:00<00:14, 175.21it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▌         | 144/2594 [00:00<00:13, 181.65it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▋         | 164/2594 [00:00<00:13, 185.65it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   7%|▋         | 183/2594 [00:01<00:12, 186.44it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|▊         | 202/2594 [00:01<00:12, 184.31it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   9%|▊         | 222/2594 [00:01<00:12, 187.18it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   9%|▉         | 243/2594 [00:01<00:12, 189.48it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█         | 263/2594 [00:01<00:12, 191.10it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  11%|█         | 283/2594 [00:01<00:12, 191.05it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█▏        | 304/2594 [00:01<00:11, 195.46it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█▏        | 324/2594 [00:01<00:11, 194.09it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  13%|█▎        | 345/2594 [00:01<00:11, 196.74it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  14%|█▍        | 365/2594 [00:01<00:11, 193.72it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  15%|█▍        | 385/2594 [00:02<00:11, 193.84it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  95%|█████████▌| 2469/2594 [00:13<00:00, 186.80it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|█████████▌| 2488/2594 [00:13<00:00, 182.39it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  97%|█████████▋| 2507/2594 [00:13<00:00, 183.56it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  97%|█████████▋| 2527/2594 [00:13<00:00, 184.75it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|█████████▊| 2546/2594 [00:13<00:00, 185.14it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  99%|█████████▉| 2566/2594 [00:13<00:00, 188.22it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|█████████▉| 2587/2594 [00:13<00:00, 191.76it/s]Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|██████████| 2594/2594 [00:13<00:00, 189.15it/s]

# %%
# Altura y Ancho de la imagen y los canales RGB para las imagenes ya redimensionadas
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = '/home/quiquealon/Documents/TIA/UNET/ISIC2018_Task1-2_Training_Input-redimensionada/'
MASK_PATH = '/home/quiquealon/Documents/TIA/UNET/ISIC2018_Task1_Training_GroundTruth-redimensionada/'


warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
train_ids = next(os.walk(TRAIN_PATH))[2]


X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

# %%
train_ids
# Out:
# ['ISIC_0013269.jpg',
#  'ISIC_0000120.jpg',
#  'ISIC_0009875.jpg',
#  'ISIC_0000050.jpg',
#  'ISIC_0000232.jpg',
#  'ISIC_0015243.jpg',
#  'ISIC_0013831.jpg',
#  'ISIC_0000431.jpg',
#  'ISIC_0000109.jpg',
#  'ISIC_0012539.jpg',
#  'ISIC_0011119.jpg',
#  'ISIC_0015244.jpg',
#  'ISIC_0014853.jpg',
#  'ISIC_0000359.jpg',
#  'ISIC_0013417.jpg',
#  'ISIC_0010341.jpg',
#  'ISIC_0002836.jpg',
#  'ISIC_0000534.jpg',
#  'ISIC_0012335.jpg',
#  'ISIC_0014985.jpg',
#  'ISIC_0013134.jpg',
#  'ISIC_0015537.jpg',
#  'ISIC_0000493.jpg',
#  'ISIC_0010020.jpg',
#  'ISIC_0015115.jpg',
#  'ISIC_0011084.jpg',
#  'ISIC_0012803.jpg',
#  'ISIC_0000222.jpg',
#  'ISIC_0010466.jpg',
#  'ISIC_0012711.jpg',
#  'ISIC_0011159.jpg',
#  'ISIC_0009915.jpg',
#  'ISIC_0010370.jpg',
#  'ISIC_0013141.jpg',
#  'ISIC_0010207.jpg',
#  'ISIC_0010238.jpg',
#  'ISIC_0000486.jpg',
#  'ISIC_0015946.jpg',
#  'ISIC_0000060.jpg',
#  'ISIC_0010037.jpg',
#  'ISIC_0012704.jpg',
#  'ISIC_0011140.jpg',
#  'ISIC_0012676.jpg',
#  'ISIC_0013498.jpg',
#  'ISIC_0012976.jpg',
#  'ISIC_0014748.jpg',
#  'ISIC_0013001.jpg',
#  'ISIC_0010472.jpg',
#  'ISIC_0011322.jpg',
#  'ISIC_0000350.jpg',
#  'ISIC_0001442.jpg',
#  'ISIC_0014581.jpg',
#  'ISIC_0014044.jpg',
#  'ISIC_0013835.jpg',
#  'ISIC_0000509.jpg',
#  'ISIC_0000448.jpg',
#  'ISIC_0013936.jpg',
#  'ISIC_0014925.jpg',
#  'ISIC_0000080.jpg',
#  'ISIC_0000365.jpg',
#  'ISIC_0014284.jpg',
#  'ISIC_0015411.jpg',
#  'ISIC_0000535.jpg',
#  'ISIC_0013970.jpg',
#  'ISIC_0000540.jpg',
#  'ISIC_0012105.jpg',
#  'ISIC_0013205.jpg',
#  'ISIC_0000008.jpg',
#  'ISIC_0014652.jpg',
#  'ISIC_0012671.jpg',
#  'ISIC_0014687.jpg',
#  'ISIC_0001262.jpg',
#  'ISIC_0013674.jpg',
#  'ISIC_0007760.jpg',
#  'ISIC_0000412.jpg',
#  'ISIC_0011292.jpg',
#  'ISIC_0011203.jpg',
#  'ISIC_0012135.jpg',
#  'ISIC_0016035.jpg',
#  'ISIC_0012475.jpg',
#  'ISIC_0011211.jpg',
#  'ISIC_0015582.jpg',
#  'ISIC_0000250.jpg',
#  'ISIC_0016019.jpg',
#  'ISIC_0000077.jpg',
#  'ISIC_0015155.jpg',
#  'ISIC_0011301.jpg',
#  'ISIC_0000097.jpg',
#  'ISIC_0013230.jpg',
#  'ISIC_0013071.jpg',
#  'ISIC_0013335.jpg',
#  'ISIC_0000507.jpg',
#  'ISIC_0010054.jpg',
#  'ISIC_0013680.jpg',
#  'ISIC_0010364.jpg',
#  'ISIC_0015037.jpg',
#  'ISIC_0013696.jpg',
#  'ISIC_0012806.jpg',
#  'ISIC_0011390.jpg',
#  'ISIC_0013193.jpg',
#  'ISIC_0014546.jpg',
#  'ISIC_0009925.jpg',
#  'ISIC_0013159.jpg',
#  'ISIC_0014661.jpg',
#  'ISIC_0012228.jpg',
#  'ISIC_0013104.jpg',
#  'ISIC_0013150.jpg',
#  'ISIC_0014722.jpg',
#  'ISIC_0000481.jpg',
#  'ISIC_0011207.jpg',
#  'ISIC_0011202.jpg',
#  'ISIC_0012109.jpg',
#  'ISIC_0012705.jpg',
#  'ISIC_0000170.jpg',
#  'ISIC_0012990.jpg',
#  'ISIC_0014746.jpg',
#  'ISIC_0013596.jpg',
#  'ISIC_0000341.jpg',
#  'ISIC_0015981.jpg',
#  'ISIC_0013424.jpg',
#  'ISIC_0014174.jpg',
#  'ISIC_0000290.jpg',
#  'ISIC_0015952.jpg',
#  'ISIC_0014998.jpg',
#  'ISIC_0014688.jpg',
#  'ISIC_0014583.jpg',
#  'ISIC_0011120.jpg',
#  'ISIC_0013200.jpg',
#  'ISIC_0016041.jpg',
#  'ISIC_0014974.jpg',
#  'ISIC_0012786.jpg',
#  'ISIC_0012684.jpg',
#  'ISIC_0012313.jpg',
#  'ISIC_0012259.jpg',
#  'ISIC_0000061.jpg',
#  'ISIC_0015144.jpg',
#  'ISIC_0012330.jpg',
#  'ISIC_0013980.jpg',
#  'ISIC_0000488.jpg',
#  'ISIC_0000022.jpg',
#  'ISIC_0013910.jpg',
#  'ISIC_0013473.jpg',
#  'ISIC_0014876.jpg',
#  'ISIC_0000200.jpg',
#  'ISIC_0000331.jpg',
#  'ISIC_0000479.jpg',
#  'ISIC_0013275.jpg',
#  'ISIC_0015944.jpg',
#  'ISIC_0000155.jpg',
#  'ISIC_0014913.jpg',
#  'ISIC_0014117.jpg',
#  'ISIC_0004337.jpg',
#  'ISIC_0013737.jpg',
#  'ISIC_0000151.jpg',
#  'ISIC_0009583.jpg',
#  'ISIC_0012325.jpg',
#  'ISIC_0014129.jpg',
#  'ISIC_0014716.jpg',
#  'ISIC_0012332.jpg',
#  'ISIC_0012272.jpg',
#  'ISIC_0015034.jpg',
#  'ISIC_0010483.jpg',
#  'ISIC_0010090.jpg',
#  'ISIC_0014545.jpg',
#  'ISIC_0000418.jpg',
#  'ISIC_0015627.jpg',
#  'ISIC_0009955.jpg',
#  'ISIC_0000259.jpg',
#  'ISIC_0000052.jpg',
#  'ISIC_0006914.jpg',
#  'ISIC_0016066.jpg',
#  'ISIC_0012338.jpg',
#  'ISIC_0014289.jpg',
#  'ISIC_0013048.jpg',
#  'ISIC_0008541.jpg',
#  'ISIC_0001213.jpg',
#  'ISIC_0015189.jpg',
#  'ISIC_0000427.jpg',
#  'ISIC_0000145.jpg',
#  'ISIC_0015031.jpg',
#  'ISIC_0000199.jpg',
#  'ISIC_0012999.jpg',
#  'ISIC_0010374.jpg',
#  'ISIC_0011383.jpg',
#  'ISIC_0013898.jpg',
#  'ISIC_0009982.jpg',
#  'ISIC_0000410.jpg',
#  'ISIC_0013274.jpg',
#  'ISIC_0010176.jpg',
#  'ISIC_0000242.jpg',
#  'ISIC_0010231.jpg',
#  'ISIC_0011223.jpg',
#  'ISIC_0000037.jpg',
#  'ISIC_0011101.jpg',
#  'ISIC_0006114.jpg',
#  'ISIC_0014982.jpg',
#  'ISIC_0009895.jpg',
#  'ISIC_0009948.jpg',
#  'ISIC_0010858.jpg',
#  'ISIC_0010350.jpg',
#  'ISIC_0014938.jpg',
#  'ISIC_0013621.jpg',
#  'ISIC_0012897.jpg',
#  'ISIC_0015544.jpg',
#  'ISIC_0000127.jpg',
#  'ISIC_0012961.jpg',
#  'ISIC_0013667.jpg',
#  'ISIC_0009978.jpg',
#  'ISIC_0000209.jpg',
#  'ISIC_0000067.jpg',
#  'ISIC_0015273.jpg',
#  'ISIC_0009992.jpg',
#  'ISIC_0009920.jpg',
#  'ISIC_0001292.jpg',
#  'ISIC_0015110.jpg',
#  'ISIC_0000537.jpg',
#  'ISIC_0012511.jpg',
#  'ISIC_0016034.jpg',
#  'ISIC_0000027.jpg',
#  'ISIC_0012681.jpg',
#  'ISIC_0000367.jpg',
#  'ISIC_0009891.jpg',
#  'ISIC_0012473.jpg',
#  'ISIC_0012871.jpg',
#  'ISIC_0014081.jpg',
#  'ISIC_0015011.jpg',
#  'ISIC_0015956.jpg',
#  'ISIC_0013233.jpg',
#  'ISIC_0012379.jpg',
#  'ISIC_0010105.jpg',
#  'ISIC_0009945.jpg',
#  'ISIC_0009873.jpg',
#  'ISIC_0010094.jpg',
#  'ISIC_0013216.jpg',
#  'ISIC_0014558.jpg',
#  'ISIC_0013512.jpg',
#  'ISIC_0014800.jpg',
#  'ISIC_0009975.jpg',
#  'ISIC_0008507.jpg',
#  'ISIC_0000095.jpg',
#  'ISIC_0005555.jpg',
#  'ISIC_0013501.jpg',
#  'ISIC_0011214.jpg',
#  'ISIC_0000538.jpg',
#  'ISIC_0014476.jpg',
#  'ISIC_0011123.jpg',
#  'ISIC_0009902.jpg',
#  'ISIC_0002948.jpg',
#  'ISIC_0010184.jpg',
#  'ISIC_0001186.jpg',
#  'ISIC_0016003.jpg',
#  'ISIC_0000164.jpg',
#  'ISIC_0014832.jpg',
#  'ISIC_0009165.jpg',
#  'ISIC_0012666.jpg',
#  'ISIC_0014975.jpg',
#  'ISIC_0015152.jpg',
#  'ISIC_0012520.jpg',
#  'ISIC_0000225.jpg',
#  'ISIC_0000055.jpg',
#  'ISIC_0007693.jpg',
#  'ISIC_0015130.jpg',
#  'ISIC_0014812.jpg',
#  'ISIC_0009344.jpg',
#  'ISIC_0014818.jpg',
#  'ISIC_0013140.jpg',
#  'ISIC_0009956.jpg',
#  'ISIC_0000264.jpg',
#  'ISIC_0015044.jpg',
#  'ISIC_0000018.jpg',
#  'ISIC_0011098.jpg',
#  'ISIC_0011097.jpg',
#  'ISIC_0014103.jpg',
#  'ISIC_0013333.jpg',
#  'ISIC_0015293.jpg',
#  'ISIC_0011139.jpg',
#  'ISIC_0014898.jpg',
#  'ISIC_0015125.jpg',
#  'ISIC_0012654.jpg',
#  'ISIC_0016024.jpg',
#  'ISIC_0007322.jpg',
#  'ISIC_0014729.jpg',
#  'ISIC_0014785.jpg',
#  'ISIC_0010452.jpg',
#  'ISIC_0014580.jpg',
#  'ISIC_0010025.jpg',
#  'ISIC_0014944.jpg',
#  'ISIC_0012306.jpg',
#  'ISIC_0014863.jpg',
#  'ISIC_0012406.jpg',
#  'ISIC_0010449.jpg',
#  'ISIC_0015641.jpg',
#  'ISIC_0011356.jpg',
#  'ISIC_0013487.jpg',
#  'ISIC_0013000.jpg',
#  'ISIC_0000011.jpg',
#  'ISIC_0014554.jpg',
#  'ISIC_0012299.jpg',
#  'ISIC_0003582.jpg',
#  'ISIC_0014665.jpg',
#  'ISIC_0012381.jpg',
#  'ISIC_0012233.jpg',
#  'ISIC_0012384.jpg',
#  'ISIC_0011171.jpg',
#  'ISIC_0013975.jpg',
#  'ISIC_0000370.jpg',
#  'ISIC_0011082.jpg',
#  'ISIC_0000447.jpg',
#  'ISIC_0014772.jpg',
#  'ISIC_0000340.jpg',
#  'ISIC_0000549.jpg',
#  'ISIC_0013996.jpg',
#  'ISIC_0014559.jpg',
#  'ISIC_0001385.jpg',
#  'ISIC_0011092.jpg',
#  'ISIC_0012836.jpg',
#  'ISIC_0000277.jpg',
#  'ISIC_0010368.jpg',
#  'ISIC_0000181.jpg',
#  'ISIC_0014080.jpg',
#  'ISIC_0014957.jpg',
#  'ISIC_0010372.jpg',
#  'ISIC_0012665.jpg',
#  'ISIC_0000093.jpg',
#  'ISIC_0013572.jpg',
#  'ISIC_0001427.jpg',
#  'ISIC_0008406.jpg',
#  'ISIC_0012496.jpg',
#  'ISIC_0014470.jpg',
#  'ISIC_0012678.jpg',
#  'ISIC_0013340.jpg',
#  'ISIC_0013983.jpg',
#  'ISIC_0013762.jpg',
#  'ISIC_0015129.jpg',
#  'ISIC_0012957.jpg',
#  'ISIC_0014848.jpg',
#  'ISIC_0014743.jpg',
#  'ISIC_0012521.jpg',
#  'ISIC_0014956.jpg',
#  'ISIC_0010227.jpg',
#  'ISIC_0012230.jpg',
#  'ISIC_0012888.jpg',
#  'ISIC_0000243.jpg',
#  'ISIC_0002879.jpg',
#  'ISIC_0013034.jpg',
#  'ISIC_0014503.jpg',
#  'ISIC_0014723.jpg',
#  'ISIC_0009160.jpg',
#  'ISIC_0014037.jpg',
#  'ISIC_0013201.jpg',
#  'ISIC_0009923.jpg',
#  'ISIC_0010852.jpg',
#  'ISIC_0014735.jpg',
#  'ISIC_0010047.jpg',
#  'ISIC_0010477.jpg',
#  'ISIC_0000165.jpg',
#  'ISIC_0013394.jpg',
#  'ISIC_0012879.jpg',
#  'ISIC_0000539.jpg',
#  'ISIC_0000058.jpg',
#  'ISIC_0013398.jpg',
#  'ISIC_0013459.jpg',
#  'ISIC_0015636.jpg',
#  'ISIC_0015226.jpg',
#  'ISIC_0010220.jpg',
#  'ISIC_0001118.jpg',
#  'ISIC_0012737.jpg',
#  'ISIC_0013702.jpg',
#  'ISIC_0013229.jpg',
#  'ISIC_0012435.jpg',
#  'ISIC_0008145.jpg',
#  'ISIC_0000013.jpg',
#  'ISIC_0000020.jpg',
#  'ISIC_0002453.jpg',
#  'ISIC_0014149.jpg',
#  'ISIC_0000100.jpg',
#  'ISIC_0011225.jpg',
#  'ISIC_0012278.jpg',
#  'ISIC_0010445.jpg',
#  'ISIC_0012160.jpg',
#  'ISIC_0012177.jpg',
#  'ISIC_0015232.jpg',
#  'ISIC_0014739.jpg',
#  'ISIC_0016071.jpg',
#  'ISIC_0013053.jpg',
#  'ISIC_0012348.jpg',
#  'ISIC_0000138.jpg',
#  'ISIC_0013673.jpg',
#  'ISIC_0014778.jpg',
#  'ISIC_0014454.jpg',
#  'ISIC_0000230.jpg',
#  'ISIC_0009969.jpg',
#  'ISIC_0012907.jpg',
#  'ISIC_0013438.jpg',
#  'ISIC_0012658.jpg',
#  'ISIC_0000119.jpg',
#  'ISIC_0013191.jpg',
#  'ISIC_0002093.jpg',
#  'ISIC_0011229.jpg',
#  'ISIC_0013075.jpg',
#  'ISIC_0009860.jpg',
#  'ISIC_0014162.jpg',
#  'ISIC_0014537.jpg',
#  'ISIC_0013562.jpg',
#  'ISIC_0013399.jpg',
#  'ISIC_0011326.jpg',
#  'ISIC_0000190.jpg',
#  'ISIC_0010562.jpg',
#  'ISIC_0015185.jpg',
#  'ISIC_0012149.jpg',
#  'ISIC_0010358.jpg',
#  'ISIC_0010337.jpg',
#  'ISIC_0014502.jpg',
#  'ISIC_0012722.jpg',
#  'ISIC_0010169.jpg',
#  'ISIC_0013356.jpg',
#  'ISIC_0015951.jpg',
#  'ISIC_0011385.jpg',
#  'ISIC_0010342.jpg',
#  'ISIC_0000517.jpg',
#  'ISIC_0010073.jpg',
#  'ISIC_0016004.jpg',
#  'ISIC_0012469.jpg',
#  'ISIC_0015270.jpg',
#  'ISIC_0014835.jpg',
#  'ISIC_0013365.jpg',
#  'ISIC_0000087.jpg',
#  'ISIC_0012092.jpg',
#  'ISIC_0014273.jpg',
#  'ISIC_0012662.jpg',
#  'ISIC_0014395.jpg',
#  'ISIC_0000069.jpg',
#  'ISIC_0014651.jpg',
#  'ISIC_0011168.jpg',
#  'ISIC_0011327.jpg',
#  'ISIC_0013166.jpg',
#  'ISIC_0009927.jpg',
#  'ISIC_0000081.jpg',
#  'ISIC_0009972.jpg',
#  'ISIC_0013235.jpg',
#  'ISIC_0015176.jpg',
#  'ISIC_0010857.jpg',
#  'ISIC_0000480.jpg',
#  'ISIC_0010574.jpg',
#  'ISIC_0010344.jpg',
#  'ISIC_0013423.jpg',
#  'ISIC_0014696.jpg',
#  'ISIC_0015997.jpg',
#  'ISIC_0000003.jpg',
#  'ISIC_0014222.jpg',
#  'ISIC_0012201.jpg',
#  'ISIC_0009990.jpg',
#  'ISIC_0011372.jpg',
#  'ISIC_0014968.jpg',
#  'ISIC_0000383.jpg',
#  'ISIC_0013287.jpg',
#  'ISIC_0010847.jpg',
#  'ISIC_0006193.jpg',
#  'ISIC_0012086.jpg',
#  'ISIC_0015291.jpg',
#  'ISIC_0013739.jpg',
#  'ISIC_0013549.jpg',
#  'ISIC_0014753.jpg',
#  'ISIC_0000528.jpg',
#  'ISIC_0014547.jpg',
#  'ISIC_0000098.jpg',
#  'ISIC_0011315.jpg',
#  'ISIC_0010174.jpg',
#  'ISIC_0015051.jpg',
#  'ISIC_0009885.jpg',
#  'ISIC_0013719.jpg',
#  'ISIC_0013369.jpg',
#  'ISIC_0013244.jpg',
#  'ISIC_0007038.jpg',
#  'ISIC_0013523.jpg',
#  'ISIC_0013738.jpg',
#  'ISIC_0015035.jpg',
#  'ISIC_0014677.jpg',
#  'ISIC_0010589.jpg',
#  'ISIC_0000281.jpg',
#  'ISIC_0015190.jpg',
#  'ISIC_0015254.jpg',
#  'ISIC_0014357.jpg',
#  'ISIC_0016063.jpg',
#  'ISIC_0010346.jpg',
#  'ISIC_0001242.jpg',
#  'ISIC_0009078.jpg',
#  'ISIC_0000330.jpg',
#  'ISIC_0010317.jpg',
#  'ISIC_0014962.jpg',
#  'ISIC_0000313.jpg',
#  'ISIC_0014302.jpg',
#  'ISIC_0011296.jpg',
#  'ISIC_0015996.jpg',
#  'ISIC_0014535.jpg',
#  'ISIC_0013208.jpg',
#  'ISIC_0011131.jpg',
#  'ISIC_0013024.jpg',
#  'ISIC_0003657.jpg',
#  'ISIC_0000547.jpg',
#  'ISIC_0014945.jpg',
#  'ISIC_0010194.jpg',
#  'ISIC_0014360.jpg',
#  'ISIC_0007087.jpg',
#  'ISIC_0013601.jpg',
#  'ISIC_0014189.jpg',
#  'ISIC_0013248.jpg',
#  'ISIC_0007796.jpg',
#  'ISIC_0010043.jpg',
#  'ISIC_0013796.jpg',
#  'ISIC_0000419.jpg',
#  'ISIC_0009934.jpg',
#  'ISIC_0013163.jpg',
#  'ISIC_0000378.jpg',
#  'ISIC_0015403.jpg',
#  'ISIC_0013594.jpg',
#  'ISIC_0012329.jpg',
#  'ISIC_0009998.jpg',
#  'ISIC_0012159.jpg',
#  'ISIC_0011114.jpg',
#  'ISIC_0016059.jpg',
#  'ISIC_0014745.jpg',
#  'ISIC_0000226.jpg',
#  'ISIC_0010585.jpg',
#  'ISIC_0000000.jpg',
#  'ISIC_0000220.jpg',
#  'ISIC_0000162.jpg',
#  'ISIC_0011210.jpg',
#  'ISIC_0013672.jpg',
#  'ISIC_0012213.jpg',
#  'ISIC_0010236.jpg',
#  'ISIC_0013037.jpg',
#  'ISIC_0000392.jpg',
#  'ISIC_0000506.jpg',
#  'ISIC_0000449.jpg',
#  'ISIC_0014806.jpg',
#  'ISIC_0013257.jpg',
#  'ISIC_0015124.jpg',
#  'ISIC_0015295.jpg',
#  'ISIC_0010237.jpg',
#  'ISIC_0010365.jpg',
#  'ISIC_0014769.jpg',
#  'ISIC_0012516.jpg',
#  'ISIC_0014682.jpg',
#  'ISIC_0014500.jpg',
#  'ISIC_0010565.jpg',
#  'ISIC_0000094.jpg',
#  'ISIC_0014697.jpg',
#  'ISIC_0015943.jpg',
#  'ISIC_0009935.jpg',
#  'ISIC_0007528.jpg',
#  'ISIC_0010180.jpg',
#  'ISIC_0014274.jpg',
#  'ISIC_0012478.jpg',
#  'ISIC_0000124.jpg',
#  'ISIC_0012989.jpg',
#  'ISIC_0012203.jpg',
#  'ISIC_0012657.jpg',
#  'ISIC_0016009.jpg',
#  'ISIC_0014742.jpg',
#  'ISIC_0011144.jpg',
#  'ISIC_0015353.jpg',
#  'ISIC_0014635.jpg',
#  'ISIC_0011328.jpg',
#  'ISIC_0016052.jpg',
#  'ISIC_0012358.jpg',
#  'ISIC_0014804.jpg',
#  'ISIC_0014730.jpg',
#  'ISIC_0000390.jpg',
#  'ISIC_0010190.jpg',
#  'ISIC_0010000.jpg',
#  'ISIC_0014702.jpg',
#  'ISIC_0000154.jpg',
#  'ISIC_0000218.jpg',
#  'ISIC_0000088.jpg',
#  'ISIC_0009929.jpg',
#  'ISIC_0014605.jpg',
#  'ISIC_0013684.jpg',
#  'ISIC_0009898.jpg',
#  'ISIC_0000202.jpg',
#  'ISIC_0014160.jpg',
#  'ISIC_0004715.jpg',
#  'ISIC_0012683.jpg',
#  'ISIC_0010219.jpg',
#  'ISIC_0014480.jpg',
#  'ISIC_0014625.jpg',
#  'ISIC_0000153.jpg',
#  'ISIC_0012417.jpg',
#  'ISIC_0013690.jpg',
#  'ISIC_0010572.jpg',
#  'ISIC_0015060.jpg',
#  'ISIC_0009953.jpg',
#  'ISIC_0012682.jpg',
#  'ISIC_0011336.jpg',
#  'ISIC_0013044.jpg',
#  'ISIC_0012495.jpg',
#  'ISIC_0000295.jpg',
#  'ISIC_0000116.jpg',
#  'ISIC_0000096.jpg',
#  'ISIC_0001140.jpg',
#  'ISIC_0013805.jpg',
#  'ISIC_0016040.jpg',
#  'ISIC_0012390.jpg',
#  'ISIC_0015998.jpg',
#  'ISIC_0013315.jpg',
#  'ISIC_0010844.jpg',
#  'ISIC_0010222.jpg',
#  'ISIC_0014108.jpg',
#  'ISIC_0009881.jpg',
#  'ISIC_0014809.jpg',
#  'ISIC_0016026.jpg',
#  'ISIC_0000426.jpg',
#  'ISIC_0012987.jpg',
#  'ISIC_0015160.jpg',
#  'ISIC_0014932.jpg',
#  'ISIC_0013432.jpg',
#  'ISIC_0013410.jpg',
#  'ISIC_0016017.jpg',
#  'ISIC_0013321.jpg',
#  'ISIC_0010595.jpg',
#  'ISIC_0011329.jpg',
#  'ISIC_0000511.jpg',
#  'ISIC_0010382.jpg',
#  'ISIC_0001852.jpg',
#  'ISIC_0013782.jpg',
#  'ISIC_0011339.jpg',
#  'ISIC_0000421.jpg',
#  'ISIC_0011081.jpg',
#  'ISIC_0010475.jpg',
#  'ISIC_0013748.jpg',
#  'ISIC_0014904.jpg',
#  'ISIC_0013015.jpg',
#  'ISIC_0012116.jpg',
#  'ISIC_0014846.jpg',
#  'ISIC_0013084.jpg',
#  'ISIC_0013815.jpg',
#  'ISIC_0014150.jpg',
#  'ISIC_0013086.jpg',
#  'ISIC_0010173.jpg',
#  'ISIC_0000210.jpg',
#  'ISIC_0000133.jpg',
#  'ISIC_0015161.jpg',
#  'ISIC_0016051.jpg',
#  'ISIC_0010465.jpg',
#  'ISIC_0000299.jpg',
#  'ISIC_0015140.jpg',
#  'ISIC_0010010.jpg',
#  'ISIC_0009877.jpg',
#  'ISIC_0009928.jpg',
#  'ISIC_0010264.jpg',
#  'ISIC_0014473.jpg',
#  'ISIC_0013397.jpg',
#  'ISIC_0000307.jpg',
#  'ISIC_0013886.jpg',
#  'ISIC_0012173.jpg',
#  'ISIC_0015966.jpg',
#  'ISIC_0010019.jpg',
#  'ISIC_0014851.jpg',
#  'ISIC_0009932.jpg',
#  'ISIC_0013325.jpg',
#  'ISIC_0013516.jpg',
#  'ISIC_0000187.jpg',
#  'ISIC_0012518.jpg',
#  'ISIC_0000490.jpg',
#  'ISIC_0000039.jpg',
#  'ISIC_0013052.jpg',
#  'ISIC_0009897.jpg',
#  'ISIC_0013443.jpg',
#  'ISIC_0000377.jpg',
#  'ISIC_0015960.jpg',
#  'ISIC_0006671.jpg',
#  'ISIC_0014664.jpg',
#  'ISIC_0013526.jpg',
#  'ISIC_0013458.jpg',
#  'ISIC_0014076.jpg',
#  'ISIC_0014836.jpg',
#  'ISIC_0012253.jpg',
#  'ISIC_0012108.jpg',
#  'ISIC_0013676.jpg',
#  'ISIC_0000215.jpg',
#  'ISIC_0001105.jpg',
#  'ISIC_0014347.jpg',
#  'ISIC_0000042.jpg',
#  'ISIC_0013070.jpg',
#  'ISIC_0009977.jpg',
#  'ISIC_0000108.jpg',
#  'ISIC_0012898.jpg',
#  'ISIC_0013204.jpg',
#  'ISIC_0000196.jpg',
#  'ISIC_0015638.jpg',
#  'ISIC_0013581.jpg',
#  'ISIC_0001142.jpg',
#  'ISIC_0008256.jpg',
#  'ISIC_0013921.jpg',
#  'ISIC_0013721.jpg',
#  'ISIC_0010439.jpg',
#  'ISIC_0004985.jpg',
#  'ISIC_0000444.jpg',
#  'ISIC_0012238.jpg',
#  'ISIC_0010235.jpg',
#  'ISIC_0012320.jpg',
#  'ISIC_0013635.jpg',
#  'ISIC_0006815.jpg',
#  'ISIC_0000465.jpg',
#  'ISIC_0010015.jpg',
#  'ISIC_0012986.jpg',
#  'ISIC_0015219.jpg',
#  'ISIC_0013220.jpg',
#  'ISIC_0015937.jpg',
#  'ISIC_0000207.jpg',
#  'ISIC_0014195.jpg',
#  'ISIC_0014600.jpg',
#  'ISIC_0014325.jpg',
#  'ISIC_0000053.jpg',
#  'ISIC_0015173.jpg',
#  'ISIC_0015971.jpg',
#  'ISIC_0013346.jpg',
#  'ISIC_0011085.jpg',
#  'ISIC_0014782.jpg',
#  'ISIC_0014795.jpg',
#  'ISIC_0009965.jpg',
#  'ISIC_0011156.jpg',
#  'ISIC_0012887.jpg',
#  'ISIC_0013129.jpg',
#  'ISIC_0014624.jpg',
#  'ISIC_0013082.jpg',
#  'ISIC_0015941.jpg',
#  'ISIC_0010853.jpg',
#  'ISIC_0014263.jpg',
#  'ISIC_0013359.jpg',
#  'ISIC_0011384.jpg',
#  'ISIC_0014253.jpg',
#  'ISIC_0000282.jpg',
#  'ISIC_0010481.jpg',
#  'ISIC_0013962.jpg',
#  'ISIC_0014225.jpg',
#  'ISIC_0009976.jpg',
#  'ISIC_0000111.jpg',
#  'ISIC_0014327.jpg',
#  'ISIC_0015157.jpg',
#  'ISIC_0000395.jpg',
#  'ISIC_0012090.jpg',
#  'ISIC_0015416.jpg',
#  'ISIC_0006800.jpg',
#  'ISIC_0012547.jpg',
#  'ISIC_0015200.jpg',
#  'ISIC_0013568.jpg',
#  'ISIC_0013226.jpg',
#  'ISIC_0000046.jpg',
#  'ISIC_0015390.jpg',
#  'ISIC_0014921.jpg',
#  'ISIC_0011228.jpg',
#  'ISIC_0014642.jpg',
#  'ISIC_0011164.jpg',
#  'ISIC_0015276.jpg',
#  'ISIC_0012248.jpg',
#  'ISIC_0012512.jpg',
#  'ISIC_0005666.jpg',
#  'ISIC_0015468.jpg',
#  'ISIC_0015139.jpg',
#  'ISIC_0013733.jpg',
#  'ISIC_0009533.jpg',
#  'ISIC_0016061.jpg',
#  'ISIC_0014979.jpg',
#  'ISIC_0000357.jpg',
#  'ISIC_0000102.jpg',
#  'ISIC_0000408.jpg',
#  'ISIC_0010480.jpg',
#  'ISIC_0000403.jpg',
#  'ISIC_0000161.jpg',
#  'ISIC_0014049.jpg',
#  'ISIC_0009962.jpg',
#  'ISIC_0014603.jpg',
#  'ISIC_0000228.jpg',
#  'ISIC_0000536.jpg',
#  'ISIC_0013691.jpg',
#  'ISIC_0013695.jpg',
#  'ISIC_0012813.jpg',
#  'ISIC_0015149.jpg',
#  'ISIC_0000283.jpg',
#  'ISIC_0000023.jpg',
#  'ISIC_0000337.jpg',
#  'ISIC_0003559.jpg',
#  'ISIC_0014754.jpg',
#  'ISIC_0010356.jpg',
#  'ISIC_0014331.jpg',
#  'ISIC_0000253.jpg',
#  'ISIC_0010241.jpg',
#  'ISIC_0000380.jpg',
#  'ISIC_0000275.jpg',
#  'ISIC_0012966.jpg',
#  'ISIC_0010362.jpg',
#  'ISIC_0013836.jpg',
#  'ISIC_0014826.jpg',
#  'ISIC_0011135.jpg',
#  'ISIC_0015994.jpg',
#  'ISIC_0000079.jpg',
#  'ISIC_0015330.jpg',
#  'ISIC_0000548.jpg',
#  'ISIC_0014787.jpg',
#  'ISIC_0000353.jpg',
#  'ISIC_0011170.jpg',
#  'ISIC_0014694.jpg',
#  'ISIC_0015203.jpg',
#  'ISIC_0013600.jpg',
#  'ISIC_0013789.jpg',
#  'ISIC_0012792.jpg',
#  'ISIC_0010041.jpg',
#  'ISIC_0014069.jpg',
#  'ISIC_0001423.jpg',
#  'ISIC_0010493.jpg',
#  'ISIC_0000261.jpg',
#  'ISIC_0011357.jpg',
#  'ISIC_0010032.jpg',
#  'ISIC_0010213.jpg',
#  'ISIC_0015987.jpg',
#  'ISIC_0011137.jpg',
#  'ISIC_0002780.jpg',
#  'ISIC_0010075.jpg',
#  'ISIC_0012840.jpg',
#  'ISIC_0009981.jpg',
#  'ISIC_0013190.jpg',
#  'ISIC_0012425.jpg',
#  'ISIC_0000482.jpg',
#  'ISIC_0014762.jpg',
#  'ISIC_0010462.jpg',
#  'ISIC_0010093.jpg',
#  'ISIC_0011099.jpg',
#  'ISIC_0013765.jpg',
#  'ISIC_0015445.jpg',
#  'ISIC_0000288.jpg',
#  'ISIC_0000147.jpg',
#  'ISIC_0013258.jpg',
#  'ISIC_0010442.jpg',
#  'ISIC_0012156.jpg',
#  'ISIC_0000382.jpg',
#  'ISIC_0013842.jpg',
#  'ISIC_0000311.jpg',
#  'ISIC_0000009.jpg',
#  'ISIC_0010320.jpg',
#  'ISIC_0006711.jpg',
#  'ISIC_0014507.jpg',
#  'ISIC_0000346.jpg',
#  'ISIC_0011079.jpg',
#  'ISIC_0015984.jpg',
#  'ISIC_0009938.jpg',
#  'ISIC_0010202.jpg',
#  'ISIC_0010347.jpg',
#  'ISIC_0010252.jpg',
#  'ISIC_0014791.jpg',
#  'ISIC_0010240.jpg',
#  'ISIC_0004115.jpg',
#  'ISIC_0013472.jpg',
#  'ISIC_0014857.jpg',
#  'ISIC_0011298.jpg',
#  'ISIC_0011343.jpg',
#  'ISIC_0013393.jpg',
#  'ISIC_0000038.jpg',
#  'ISIC_0012260.jpg',
#  'ISIC_0013626.jpg',
#  'ISIC_0010864.jpg',
#  'ISIC_0000530.jpg',
#  'ISIC_0015064.jpg',
#  'ISIC_0002806.jpg',
#  'ISIC_0010479.jpg',
#  'ISIC_0009949.jpg',
#  'ISIC_0000453.jpg',
#  'ISIC_0014156.jpg',
#  'ISIC_0000107.jpg',
#  'ISIC_0016033.jpg',
#  'ISIC_0014963.jpg',
#  'ISIC_0013212.jpg',
#  'ISIC_0011112.jpg',
#  'ISIC_0013972.jpg',
#  'ISIC_0010333.jpg',
#  'ISIC_0013793.jpg',
#  'ISIC_0014947.jpg',
#  'ISIC_0014542.jpg',
#  'ISIC_0001185.jpg',
#  'ISIC_0000523.jpg',
#  'ISIC_0013181.jpg',
#  'ISIC_0014434.jpg',
#  'ISIC_0011382.jpg',
#  'ISIC_0012223.jpg',
#  'ISIC_0011128.jpg',
#  'ISIC_0009971.jpg',
#  'ISIC_0014820.jpg',
#  'ISIC_0015961.jpg',
#  'ISIC_0010182.jpg',
#  'ISIC_0010458.jpg',
#  'ISIC_0011219.jpg',
#  'ISIC_0014394.jpg',
#  'ISIC_0000443.jpg',
#  'ISIC_0012316.jpg',
#  'ISIC_0014983.jpg',
#  'ISIC_0000048.jpg',
#  'ISIC_0015526.jpg',
#  'ISIC_0000416.jpg',
#  'ISIC_0000208.jpg',
#  'ISIC_0015603.jpg',
#  'ISIC_0012314.jpg',
#  'ISIC_0013433.jpg',
#  'ISIC_0000265.jpg',
#  'ISIC_0009758.jpg',
#  'ISIC_0011353.jpg',
#  'ISIC_0013320.jpg',
#  'ISIC_0015284.jpg',
#  'ISIC_0010092.jpg',
#  'ISIC_0015985.jpg',
#  'ISIC_0013651.jpg',
#  'ISIC_0013427.jpg',
#  'ISIC_0013637.jpg',
#  'ISIC_0015625.jpg',
#  'ISIC_0015948.jpg',
#  'ISIC_0011204.jpg',
#  'ISIC_0010846.jpg',
#  'ISIC_0013023.jpg',
#  'ISIC_0010212.jpg',
#  'ISIC_0012814.jpg',
#  'ISIC_0012880.jpg',
#  'ISIC_0000089.jpg',
#  'ISIC_0013558.jpg',
#  'ISIC_0014441.jpg',
#  'ISIC_0007475.jpg',
#  'ISIC_0005548.jpg',
#  'ISIC_0014093.jpg',
#  'ISIC_0001103.jpg',
#  'ISIC_0016055.jpg',
#  'ISIC_0013223.jpg',
#  'ISIC_0013592.jpg',
#  'ISIC_0014457.jpg',
#  'ISIC_0013219.jpg',
#  'ISIC_0001449.jpg',
#  'ISIC_0014543.jpg',
#  'ISIC_0014422.jpg',
#  'ISIC_0012719.jpg',
#  'ISIC_0012550.jpg',
#  'ISIC_0014680.jpg',
#  'ISIC_0015483.jpg',
#  'ISIC_0013288.jpg',
#  'ISIC_0010038.jpg',
#  'ISIC_0013187.jpg',
#  'ISIC_0000545.jpg',
#  'ISIC_0014890.jpg',
#  'ISIC_0000420.jpg',
#  'ISIC_0014397.jpg',
#  'ISIC_0010319.jpg',
#  'ISIC_0009931.jpg',
#  'ISIC_0014144.jpg',
#  'ISIC_0000339.jpg',
#  'ISIC_0010053.jpg',
#  'ISIC_0012529.jpg',
#  'ISIC_0002489.jpg',
#  'ISIC_0014046.jpg',
#  'ISIC_0015015.jpg',
#  'ISIC_0000298.jpg',
#  'ISIC_0009884.jpg',
#  'ISIC_0012445.jpg',
#  'ISIC_0013958.jpg',
#  'ISIC_0010457.jpg',
#  'ISIC_0000456.jpg',
#  'ISIC_0000364.jpg',
#  'ISIC_0000235.jpg',
#  'ISIC_0011386.jpg',
#  'ISIC_0014907.jpg',
#  'ISIC_0013529.jpg',
#  'ISIC_0013577.jpg',
#  'ISIC_0000379.jpg',
#  'ISIC_0008807.jpg',
#  'ISIC_0012930.jpg',
#  'ISIC_0012669.jpg',
#  'ISIC_0014291.jpg',
#  'ISIC_0014164.jpg',
#  'ISIC_0009297.jpg',
#  'ISIC_0011199.jpg',
#  'ISIC_0011176.jpg',
#  'ISIC_0012715.jpg',
#  'ISIC_0014073.jpg',
#  'ISIC_0012510.jpg',
#  'ISIC_0000527.jpg',
#  'ISIC_0009961.jpg',
#  'ISIC_0015005.jpg',
#  'ISIC_0001119.jpg',
#  'ISIC_0009909.jpg',
#  'ISIC_0000436.jpg',
#  'ISIC_0013491.jpg',
#  'ISIC_0014185.jpg',
#  'ISIC_0014469.jpg',
#  'ISIC_0010496.jpg',
#  'ISIC_0015274.jpg',
#  'ISIC_0013634.jpg',
#  'ISIC_0011158.jpg',
#  'ISIC_0012674.jpg',
#  'ISIC_0013474.jpg',
#  'ISIC_0011303.jpg',
#  'ISIC_0009564.jpg',
#  'ISIC_0013578.jpg',
#  'ISIC_0002829.jpg',
#  'ISIC_0010498.jpg',
#  'ISIC_0014639.jpg',
#  ...]

# %%
print('Obteniendo las imágenes ya redimensionadas de entrenamiento y máscaras. ... ')

sys.stdout.flush()

for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    
    path = TRAIN_PATH + id_
    img = imread(path)[:,:,:IMG_CHANNELS]
    X_train[n] = img
    
      
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    path_mask=MASK_PATH + id_[:-4] + '_segmentation.png'
    img_mask = imread(path_mask)
    img_mask = np.expand_dims(img_mask, axis=-1)
    
    mask = np.maximum(mask, img_mask)
    
    Y_train[n]=img_mask
    
    

print('Terminado!')
# Out:
# Obteniendo las imágenes ya redimensionadas de entrenamiento y máscaras. ...
# 100%|██████████| 2594/2594 [00:03<00:00, 710.97it/s]
# Terminado!

# %%
# Ver la data para verificar que esta leyendo bien

ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
# Metrica Jaccard o IoU (Intersection sobre union) 

def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
# Metrica Dice
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
# Funcion de perdida Dice
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
# Modelo de la U-Net

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[dice_coef])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 128, 128, 16) 448         lambda_4[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 128, 128, 16) 0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 128, 128, 16) 2320        dropout_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 64, 64, 32)   0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 32)   9248        dropout_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 64)   18496       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 32, 32, 64)   0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 64)   36928       dropout_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 16, 16, 128)  73856       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 16, 16, 128)  0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 16, 16, 128)  147584      dropout_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 128)    0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 8, 8, 256)    295168      max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 8, 8, 256)    0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 8, 8, 256)    590080      dropout_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 16, 16, 128)  131200      conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 256)  0           conv2d_transpose_13[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 16, 16, 128)  0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 16, 16, 128)  147584      dropout_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 32, 32, 64)   32832       conv2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 32, 32, 128)  0           conv2d_transpose_14[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_14[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 32, 32, 64)   0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 64)   36928       dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 64, 64, 32)   8224        conv2d_71[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 64)   0           conv2d_transpose_15[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_15[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 64, 64, 32)   0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 64, 32)   9248        dropout_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 128, 128, 16) 2064        conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 128, 128, 32) 0           conv2d_transpose_16[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_16[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 128, 128, 16) 0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 128, 128, 16) 2320        dropout_36[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 128, 128, 1)  17          conv2d_75[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit modelo
# earlystopper = EarlyStopping(patience=5, verbose=1)
# checkpointer = ModelCheckpoint('Modelo_v001.h5', verbose=1, save_best_only=True)
checkpointer = ModelCheckpoint('Modelo_v001.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50,callbacks=[checkpointer])

model.save('Modelo_v001_final.h5')
# Out:
# Train on 2334 samples, validate on 260 samples
# Epoch 1/50
# 2334/2334 [==============================] - 39s 17ms/step - loss: 0.3435 - dice_coef: 0.5610 - val_loss: 0.2837 - val_dice_coef: 0.6851
#
# Epoch 00001: val_loss improved from inf to 0.28368, saving model to Modelo_v001.h5
# Epoch 2/50
# 2334/2334 [==============================] - 33s 14ms/step - loss: 0.2287 - dice_coef: 0.7133 - val_loss: 0.2259 - val_dice_coef: 0.7057
#
# Epoch 00002: val_loss improved from 0.28368 to 0.22594, saving model to Modelo_v001.h5
# Epoch 3/50
# 2334/2334 [==============================] - 41s 18ms/step - loss: 0.1939 - dice_coef: 0.7564 - val_loss: 0.3218 - val_dice_coef: 0.6577
#
# Epoch 00003: val_loss did not improve from 0.22594
# Epoch 4/50
# 2334/2334 [==============================] - 45s 19ms/step - loss: 0.1869 - dice_coef: 0.7637 - val_loss: 0.1879 - val_dice_coef: 0.7720
#
# Epoch 00004: val_loss improved from 0.22594 to 0.18791, saving model to Modelo_v001.h5
# Epoch 5/50
# 2334/2334 [==============================] - 50s 22ms/step - loss: 0.1745 - dice_coef: 0.7805 - val_loss: 0.2038 - val_dice_coef: 0.7712
#
# Epoch 00005: val_loss did not improve from 0.18791
# Epoch 6/50
# 2334/2334 [==============================] - 50s 22ms/step - loss: 0.1674 - dice_coef: 0.7857 - val_loss: 0.2043 - val_dice_coef: 0.8035
#
# Epoch 00006: val_loss did not improve from 0.18791
# Epoch 7/50
# 2334/2334 [==============================] - 50s 22ms/step - loss: 0.1529 - dice_coef: 0.8059 - val_loss: 0.1925 - val_dice_coef: 0.7591
#
# Epoch 00007: val_loss did not improve from 0.18791
# Epoch 8/50
# 2334/2334 [==============================] - 62s 27ms/step - loss: 0.1569 - dice_coef: 0.7999 - val_loss: 0.1843 - val_dice_coef: 0.7591
#
# Epoch 00008: val_loss improved from 0.18791 to 0.18425, saving model to Modelo_v001.h5
# Epoch 9/50
# 2334/2334 [==============================] - 62s 27ms/step - loss: 0.1436 - dice_coef: 0.8164 - val_loss: 0.1815 - val_dice_coef: 0.7461
#
# Epoch 00009: val_loss improved from 0.18425 to 0.18146, saving model to Modelo_v001.h5
# Epoch 10/50
# 2334/2334 [==============================] - 60s 26ms/step - loss: 0.1409 - dice_coef: 0.8198 - val_loss: 0.1967 - val_dice_coef: 0.8063
#
# Epoch 00010: val_loss did not improve from 0.18146
# Epoch 11/50
# 2334/2334 [==============================] - 81s 35ms/step - loss: 0.1329 - dice_coef: 0.8300 - val_loss: 0.1837 - val_dice_coef: 0.7952
#
# Epoch 00011: val_loss did not improve from 0.18146
# Epoch 12/50
# 2334/2334 [==============================] - 77s 33ms/step - loss: 0.1281 - dice_coef: 0.8347 - val_loss: 0.1743 - val_dice_coef: 0.7853
#
# Epoch 00012: val_loss improved from 0.18146 to 0.17430, saving model to Modelo_v001.h5
# Epoch 13/50
# 2334/2334 [==============================] - 75s 32ms/step - loss: 0.1287 - dice_coef: 0.8348 - val_loss: 0.1795 - val_dice_coef: 0.7977
#
# Epoch 00013: val_loss did not improve from 0.17430
# Epoch 14/50
# 2334/2334 [==============================] - 69s 29ms/step - loss: 0.1245 - dice_coef: 0.8424 - val_loss: 0.1567 - val_dice_coef: 0.8179
#
# Epoch 00014: val_loss improved from 0.17430 to 0.15669, saving model to Modelo_v001.h5
# Epoch 15/50
# 2334/2334 [==============================] - 59s 25ms/step - loss: 0.1146 - dice_coef: 0.8515 - val_loss: 0.1441 - val_dice_coef: 0.8418
#
# Epoch 00015: val_loss improved from 0.15669 to 0.14406, saving model to Modelo_v001.h5
# Epoch 16/50
# 2334/2334 [==============================] - 59s 25ms/step - loss: 0.1113 - dice_coef: 0.8559 - val_loss: 0.2209 - val_dice_coef: 0.7929
#
# Epoch 00016: val_loss did not improve from 0.14406
# Epoch 17/50
# 2334/2334 [==============================] - 59s 25ms/step - loss: 0.1056 - dice_coef: 0.8638 - val_loss: 0.1781 - val_dice_coef: 0.8326
#
# Epoch 00017: val_loss did not improve from 0.14406
# Epoch 18/50
# 2334/2334 [==============================] - 59s 25ms/step - loss: 0.1148 - dice_coef: 0.8526 - val_loss: 0.1860 - val_dice_coef: 0.8049
#
# Epoch 00018: val_loss did not improve from 0.14406
# Epoch 19/50
# 2334/2334 [==============================] - 59s 25ms/step - loss: 0.1003 - dice_coef: 0.8680 - val_loss: 0.1682 - val_dice_coef: 0.8415
#
# Epoch 00019: val_loss did not improve from 0.14406
# Epoch 20/50
# 2334/2334 [==============================] - 59s 25ms/step - loss: 0.0922 - dice_coef: 0.8786 - val_loss: 0.1410 - val_dice_coef: 0.8338
#
# Epoch 00020: val_loss improved from 0.14406 to 0.14102, saving model to Modelo_v001.h5
# Epoch 21/50
# 2334/2334 [==============================] - 70s 30ms/step - loss: 0.0868 - dice_coef: 0.8853 - val_loss: 0.1507 - val_dice_coef: 0.8464
#
# Epoch 00021: val_loss did not improve from 0.14102
# Epoch 22/50
# 2334/2334 [==============================] - 81s 35ms/step - loss: 0.0817 - dice_coef: 0.8916 - val_loss: 0.1805 - val_dice_coef: 0.8258
#
# Epoch 00022: val_loss did not improve from 0.14102
# Epoch 23/50
# 2334/2334 [==============================] - 82s 35ms/step - loss: 0.0796 - dice_coef: 0.8938 - val_loss: 0.1790 - val_dice_coef: 0.8452
#
# Epoch 00023: val_loss did not improve from 0.14102
# Epoch 24/50
# 2334/2334 [==============================] - 82s 35ms/step - loss: 0.0745 - dice_coef: 0.9017 - val_loss: 0.1540 - val_dice_coef: 0.8421
#
# Epoch 00024: val_loss did not improve from 0.14102
# Epoch 25/50
# 2334/2334 [==============================] - 82s 35ms/step - loss: 0.0712 - dice_coef: 0.9049 - val_loss: 0.1597 - val_dice_coef: 0.8437
#
# Epoch 00025: val_loss did not improve from 0.14102
# Epoch 26/50
# 2334/2334 [==============================] - 82s 35ms/step - loss: 0.0781 - dice_coef: 0.8961 - val_loss: 0.1786 - val_dice_coef: 0.8435
#
# Epoch 00026: val_loss did not improve from 0.14102
# Epoch 27/50
# 2334/2334 [==============================] - 64s 27ms/step - loss: 0.0782 - dice_coef: 0.8962 - val_loss: 0.1596 - val_dice_coef: 0.8489
#
# Epoch 00027: val_loss did not improve from 0.14102
# Epoch 28/50
# 2334/2334 [==============================] - 76s 32ms/step - loss: 0.0771 - dice_coef: 0.8974 - val_loss: 0.1853 - val_dice_coef: 0.8410
#
# Epoch 00028: val_loss did not improve from 0.14102
# Epoch 29/50
# 2334/2334 [==============================] - 83s 36ms/step - loss: 0.0726 - dice_coef: 0.9033 - val_loss: 0.1889 - val_dice_coef: 0.8473
#
# Epoch 00029: val_loss did not improve from 0.14102
# Epoch 30/50
# 2334/2334 [==============================] - 78s 33ms/step - loss: 0.0665 - dice_coef: 0.9110 - val_loss: 0.1710 - val_dice_coef: 0.8567
#
# Epoch 00030: val_loss did not improve from 0.14102
# Epoch 31/50
# 2334/2334 [==============================] - 65s 28ms/step - loss: 0.0614 - dice_coef: 0.9177 - val_loss: 0.1873 - val_dice_coef: 0.8528
#
# Epoch 00031: val_loss did not improve from 0.14102
# Epoch 32/50
# 2334/2334 [==============================] - 71s 31ms/step - loss: 0.0607 - dice_coef: 0.9185 - val_loss: 0.1767 - val_dice_coef: 0.8536
#
# Epoch 00032: val_loss did not improve from 0.14102
# Epoch 33/50
# 2334/2334 [==============================] - 74s 32ms/step - loss: 0.0589 - dice_coef: 0.9204 - val_loss: 0.1853 - val_dice_coef: 0.8513
#
# Epoch 00033: val_loss did not improve from 0.14102
# Epoch 34/50
# 2334/2334 [==============================] - 70s 30ms/step - loss: 0.0604 - dice_coef: 0.9189 - val_loss: 0.1749 - val_dice_coef: 0.8421
#
# Epoch 00034: val_loss did not improve from 0.14102
# Epoch 35/50
# 2334/2334 [==============================] - 72s 31ms/step - loss: 0.0679 - dice_coef: 0.9098 - val_loss: 0.1915 - val_dice_coef: 0.8412
#
# Epoch 00035: val_loss did not improve from 0.14102
# Epoch 36/50
# 2334/2334 [==============================] - 82s 35ms/step - loss: 0.0616 - dice_coef: 0.9171 - val_loss: 0.1973 - val_dice_coef: 0.8485
#
# Epoch 00036: val_loss did not improve from 0.14102
# Epoch 37/50
# 2334/2334 [==============================] - 82s 35ms/step - loss: 0.0600 - dice_coef: 0.9189 - val_loss: 0.1875 - val_dice_coef: 0.8524
#
# Epoch 00037: val_loss did not improve from 0.14102
# Epoch 38/50
# 2334/2334 [==============================] - 85s 36ms/step - loss: 0.0572 - dice_coef: 0.9233 - val_loss: 0.1873 - val_dice_coef: 0.8550
#
# Epoch 00038: val_loss did not improve from 0.14102
# Epoch 39/50
# 2334/2334 [==============================] - 85s 36ms/step - loss: 0.0590 - dice_coef: 0.9206 - val_loss: 0.2210 - val_dice_coef: 0.8465
#
# Epoch 00039: val_loss did not improve from 0.14102
# Epoch 40/50
# 2334/2334 [==============================] - 80s 34ms/step - loss: 0.0595 - dice_coef: 0.9200 - val_loss: 0.1963 - val_dice_coef: 0.8599
#
# Epoch 00040: val_loss did not improve from 0.14102
# Epoch 41/50
# 2334/2334 [==============================] - 74s 32ms/step - loss: 0.0562 - dice_coef: 0.9243 - val_loss: 0.1846 - val_dice_coef: 0.8574
#
# Epoch 00041: val_loss did not improve from 0.14102
# Epoch 42/50
# 2334/2334 [==============================] - 51s 22ms/step - loss: 0.0553 - dice_coef: 0.9257 - val_loss: 0.1923 - val_dice_coef: 0.8598
#
# Epoch 00042: val_loss did not improve from 0.14102
# Epoch 43/50
# 2334/2334 [==============================] - 48s 20ms/step - loss: 0.0525 - dice_coef: 0.9293 - val_loss: 0.2080 - val_dice_coef: 0.8495
#
# Epoch 00043: val_loss did not improve from 0.14102
# Epoch 44/50
# 2334/2334 [==============================] - 49s 21ms/step - loss: 0.0525 - dice_coef: 0.9290 - val_loss: 0.1865 - val_dice_coef: 0.8640
#
# Epoch 00044: val_loss did not improve from 0.14102
# Epoch 45/50
# 2334/2334 [==============================] - 66s 28ms/step - loss: 0.0555 - dice_coef: 0.9259 - val_loss: 0.1880 - val_dice_coef: 0.8559
#
# Epoch 00045: val_loss did not improve from 0.14102
# Epoch 46/50
# 2334/2334 [==============================] - 68s 29ms/step - loss: 0.0532 - dice_coef: 0.9284 - val_loss: 0.2157 - val_dice_coef: 0.8403
#
# Epoch 00046: val_loss did not improve from 0.14102
# Epoch 47/50
# 2334/2334 [==============================] - 71s 30ms/step - loss: 0.0517 - dice_coef: 0.9302 - val_loss: 0.2289 - val_dice_coef: 0.8543
#
# Epoch 00047: val_loss did not improve from 0.14102
# Epoch 48/50
# 2334/2334 [==============================] - 76s 32ms/step - loss: 0.0509 - dice_coef: 0.9314 - val_loss: 0.2299 - val_dice_coef: 0.8518
#
# Epoch 00048: val_loss did not improve from 0.14102
# Epoch 49/50
# 2334/2334 [==============================] - 69s 29ms/step - loss: 0.0485 - dice_coef: 0.9341 - val_loss: 0.2540 - val_dice_coef: 0.8532
#
# Epoch 00049: val_loss did not improve from 0.14102
# Epoch 50/50
# 2334/2334 [==============================] - 68s 29ms/step - loss: 0.0468 - dice_coef: 0.9365 - val_loss: 0.2475 - val_dice_coef: 0.8472
#
# Epoch 00050: val_loss did not improve from 0.14102

# %%
# Path de las imagenes para el test

TEST_PATH = '/home/quiquealon/Documents/TIA/UNET/ISIC2018_Task1-2_Validation_Input/'
test_ids = next(os.walk(TEST_PATH))[2]

# %%
# Redimensionar Imagenes para el test

IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Obteniendo y redimensionando imágenes de prueba. ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path)[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img
    
print('Preprocesamiento Terminado!')
# Out:
# Obteniendo y redimensionando imágenes de prueba. ...
# 100%|██████████| 100/100 [04:36<00:00,  2.77s/it]
# Preprocesamiento Terminado!

# %%
# Guardar la data redimensionada del test

for id_ in tqdm(range(len(X_test)),total=len(X_test)):
    imsave('ISIC2018_Task1-2_Validation_Input-redimensionada/' + test_ids[id_],X_test[id_])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 734.90it/s]

# %%
# Obtener imagenes redimensionadas para el test

IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

TEST_PATH = '/home/quiquealon/Documents/TIA/UNET/ISIC2018_Task1-2_Validation_Input-redimensionada/'
test_ids = next(os.walk(TEST_PATH))[2]


X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Obteniendo imágenes redimensionadas de prueba. ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path)[:,:,:IMG_CHANNELS]
    X_test[n] = img
    
print('Carga Terminada!')
# Out:
# Obteniendo imágenes redimensionadas de prueba. ...
# 100%|██████████| 100/100 [00:00<00:00, 262.67it/s]
# Carga Terminada!

# %%
# Cargar modelo

model = load_model('Modelo_v001_final.h5', custom_objects={'dice_coef': dice_coef})

# %%
# Predecir en validation test

preds_test = model.predict(X_test, verbose=1)
# Out:
# 100/100 [==============================] - 6s 60ms/step

# %%
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# %%
ix = random.randint(0, len(X_test))

imshow(X_test[ix])
plt.show()

imshow(np.squeeze(preds_test[ix]))
plt.show()

imshow(np.squeeze(preds_test_t[ix]))
plt.show()

# %%
# Predecir en el train

preds_train = model.predict(X_train, verbose=1)
# Out:
# 2594/2594 [==============================] - 8s 3ms/step

# %%
preds_train_t = (preds_train > 0.5).astype(np.uint8)

# %%
ix = random.randint(0, len(preds_train_t))

imshow(X_train[ix])
plt.show()

imshow(np.squeeze(Y_train[ix]))
plt.show()

imshow(np.squeeze(preds_train_t[ix]))
plt.show()
